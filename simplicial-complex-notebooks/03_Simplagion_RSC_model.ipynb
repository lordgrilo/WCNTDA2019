# %%
import networkx as nx
import numpy as np
from scipy import random
import copy
import random
from collections import OrderedDict
import pickle
import itertools
from multiprocessing import Pool
from utils_simplagion_on_RSC import *

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Simplicial complex parameters
N = 2000
k1 = 20
k2 = 6

p1, p2 = get_p1_and_p2(k1,k2,N)

#Infection parameters
mu = 0.05
lambda1s = np.linspace(0.2,2.2,30)
lambdaD_target_list = [2.5,2.5,0.8,0]
I_percentage_list = [40,1,1,1] #initial conditions (% of infected)


#Simulation Parameters
t_max = 6000
n_simulations = 120

out_dir = './Results/'

# %%
# !mkdir ./Results
# Out:
# mkdir: ./Results: File exists

# %%
iteration_numbers = range(n_simulations)

for lambdaD_target, I_percentage in zip(lambdaD_target_list, I_percentage_list):
    print('lambdaD', lambdaD_target, 'seed', I_percentage)

    ################################ Preparing arguments for the parallel processing
    args=[]
    for it_num in range(n_simulations):
        args.append([it_num, N, p1, p2, lambda1s, lambdaD_target, I_percentage, t_max, mu])

    ################################ Running in parallel
    pool = Pool(processes=8)                         
    results = pool.map(run_one_simulation, args)
    
    ################################ Saving
    filename = 'result_RSC_'+'N'+str(N)+'_k'+str(k1)+'_kD'+str(k2)+'_mu'+str(mu)+'_lD'+str(lambdaD_target)+'_seed'+str(I_percentage)+'.p'
    pickle.dump(results, open(out_dir+filename, "wb" ))
# Out:
# lambdaD 0 seed 1
# It 8 initialized
# It 0 initialized
# It 4 initialized
# It 12 initialized
# It 20 initialized
# It 24 initialized
# It 16 initialized
# It 28 initialized
# not connected, but GC has order  1999 and size 8141
# not connected, but GC has order  1999 and size 8141
# not connected, but GC has order  1999 and size 8012
# not connected, but GC has order  1998 and size 8165
# not connected, but GC has order  1999 and size 8006
# It 8, created SC with k1=19.9 and k2=6.0
# It 20, created SC with k1=20.1 and k2=6.0
# It 24, created SC with k1=20.2 and k2=6.1
# It 12, created SC with k1=20.1 and k2=6.0
# It 4, created SC with k1=19.7 and k2=5.9
# It 0, created SC with k1=20.3 and k2=6.1
# It 28, created SC with k1=19.8 and k2=5.9
# It 16, created SC with k1=19.7 and k2=5.8
# It 4, simulation has finished
# It 5 initialized
# It 8, simulation has finished
# It 9 initialized
# not connected, but GC has order  1999 and size 7853
# It 20, simulation has finished
# It 21 initialized
# It 24, simulation has finished
# It 25 initialized
# It 16, simulation has finished
# It 17 initialized
# not connected, but GC has order  1998 and size 8000
# It 28, simulation has finished
# It 29 initialized
# It 12, simulation has finished
# It 13 initialized
# It 0, simulation has finished
# It 1 initialized
# It 25, created SC with k1=19.4 and k2=5.8
# It 5, created SC with k1=20.0 and k2=6.1
# It 17, created SC with k1=20.0 and k2=6.1
# It 9, created SC with k1=20.0 and k2=6.0
# It 21, created SC with k1=19.9 and k2=5.9
# It 29, created SC with k1=19.9 and k2=6.0
# It 13, created SC with k1=20.2 and k2=6.1
# It 1, created SC with k1=20.0 and k2=6.0
# It 25, simulation has finished
# It 26 initialized
# It 5, simulation has finished
# It 6 initialized
# It 21, simulation has finished
# It 22 initialized
# It 17, simulation has finished
# It 18 initialized
# It 9, simulation has finished
# It 10 initialized
# It 29, simulation has finished
# It 30 initialized
# It 13, simulation has finished
# It 14 initialized
# It 1, simulation has finished
# It 2 initialized
# It 26, created SC with k1=20.0 and k2=6.0
# It 6, created SC with k1=19.9 and k2=6.0
# It 22, created SC with k1=19.7 and k2=5.9
# It 18, created SC with k1=20.0 and k2=6.0
# It 30, created SC with k1=20.2 and k2=6.1
# It 10, created SC with k1=19.5 and k2=5.9
# It 14, created SC with k1=20.3 and k2=6.1
# It 2, created SC with k1=20.0 and k2=6.0
# It 26, simulation has finished
# It 27 initialized
# It 6, simulation has finished
# It 7 initialized
# not connected, but GC has order  1998 and size 8014
# It 22, simulation has finished
# It 23 initialized
# It 10, simulation has finished
# It 11 initialized
# It 18, simulation has finished
# It 19 initialized
# It 30, simulation has finished
# It 31 initialized
# It 14, simulation has finished
# It 15 initialized
# not connected, but GC has order  1997 and size 7901
# It 2, simulation has finished
# It 3 initialized
# not connected, but GC has order  1999 and size 8272
# It 27, created SC with k1=19.7 and k2=5.8
# It 7, created SC with k1=19.8 and k2=5.9
# It 23, created SC with k1=19.7 and k2=5.9
# It 11, created SC with k1=19.9 and k2=5.9
# It 19, created SC with k1=20.1 and k2=6.1
# It 15, created SC with k1=19.9 and k2=6.0
# It 31, created SC with k1=20.1 and k2=6.0
# It 3, created SC with k1=20.2 and k2=6.0
# It 27, simulation has finished
# It 32 initialized
# not connected, but GC has order  1999 and size 8000
# It 7, simulation has finished
# It 36 initialized
# not connected, but GC has order  1999 and size 7889
# It 23, simulation has finished
# It 40 initialized
# not connected, but GC has order  1999 and size 7959
# It 11, simulation has finished
# It 44 initialized
# It 19, simulation has finished
# It 48 initialized
# not connected, but GC has order  1999 and size 8134
# It 15, simulation has finished
# It 52 initialized
# not connected, but GC has order  1998 and size 8015
# It 31, simulation has finished
# It 56 initialized
# It 3, simulation has finished
# It 60 initialized
# not connected, but GC has order  1999 and size 7943
# It 32, created SC with k1=20.0 and k2=6.0
# It 36, created SC with k1=19.9 and k2=6.0
# It 40, created SC with k1=19.5 and k2=5.8
# It 52, created SC with k1=20.3 and k2=6.2
# It 44, created SC with k1=20.3 and k2=6.1
# It 48, created SC with k1=20.0 and k2=6.0
# It 60, created SC with k1=20.1 and k2=6.1
# It 56, created SC with k1=20.2 and k2=6.2
# It 32, simulation has finished
# It 33 initialized
# not connected, but GC has order  1999 and size 8031
# It 36, simulation has finished
# It 37 initialized
# not connected, but GC has order  1999 and size 8045
# It 40, simulation has finished
# It 41 initialized
# It 52, simulation has finished
# It 53 initialized
# It 44, simulation has finished
# It 45 initialized
# It 48, simulation has finished
# It 49 initialized
# not connected, but GC has order  1999 and size 8034
# It 60, simulation has finished
# It 61 initialized
# not connected, but GC has order  1998 and size 7999
# It 56, simulation has finished
# It 57 initialized
# not connected, but GC has order  1999 and size 8163
# It 33, created SC with k1=20.0 and k2=6.0
# It 37, created SC with k1=19.6 and k2=5.8
# It 41, created SC with k1=20.1 and k2=6.1
# It 53, created SC with k1=19.5 and k2=5.8
# It 45, created SC with k1=20.1 and k2=6.0
# It 61, created SC with k1=20.2 and k2=6.2
# It 49, created SC with k1=19.8 and k2=5.9
# It 57, created SC with k1=19.8 and k2=5.9

# %% [markdown]
# ## Plotting

# %%
N = 2000
k1 = 20
k2 = 6
cut = True
lambda1s = np.linspace(0.2,2.2,30)
lambdaD_target_list = [2.5,2.5,0.8,0]
I_percentage_list = [40,1,1,1] #initial conditions (% of infected)
mu = 0.05
out_dir = '../Results/'

############################# Preparing MF
MF_x=np.linspace(0.2,2.2,200)

MF_y_dict = {}

for i, (lambdaD_target, I_percentage) in enumerate(zip(lambdaD_target_list, I_percentage_list)):
    
    if i != 1:
        filename = 'result_RSC_'+'N'+str(N)+'_k'+str(k1)+'_kD'+str(k2)+'_mu'+str(mu)+'_lD'+str(lambdaD_target)+'_seed'+str(I_percentage)+'.p'
        results = pickle.load(open(out_dir+filename, "rb" ))
        _, avg_k, avg_kD = parse_results(results, cut=cut)

        beta2 = (mu*lambdaD_target)/k2
        real_lambdaD = 1.*(beta2*avg_kD)/mu
        
        #fixing for lD=0:
        if real_lambdaD==0: real_lambdaD = 0.0000001

        MF_y = map(lambda xx: get_rho_MF(xx, real_lambdaD), MF_x)
        MF_y_dict[i] = MF_y

# %%
plt.rcParams['text.usetex'] = True 
plt.rcParams['text.latex.preamble'] = [r'\usepackage[helvet]{sfmath}']
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'helvetica'
fig = plt.figure(figsize=(4.5,3));
plt.rcParams['xtick.major.width'] = 1.2
plt.rcParams['ytick.major.width'] = 1.2
plt.rcParams['axes.linewidth'] = 1.2

markers = ['o','o','s','o']
zorders = [8,7,6,5]
mfcs = ['white', 'white', 'white', 'cornflowerblue']
lables = [r'$\lambda_\Delta=2.5$','',r'$\lambda_\Delta=0.8$', r'$\lambda_\Delta=0$']
markersizes = [7.5,7.5,7,6]

ax = plt.subplot(111)

for i, (lambdaD_target, I_percentage) in enumerate(zip(lambdaD_target_list, I_percentage_list)):
    filename = 'result_RSC_'+'N'+str(N)+'_k'+str(k1)+'_kD'+str(k2)+'_mu'+str(mu)+'_lD'+str(lambdaD_target)+'_seed'+str(I_percentage)+'.p'
    results = pickle.load(open(out_dir+filename, "rb" ))
    avg_rhos, avg_k, avg_kD = parse_results(results, cut=cut)
    
    ax.plot(lambda1s, avg_rhos, markers[i], color='black', zorder=zorders[i],
            mfc=mfcs[i], markersize=markersizes[i], label=lables[i])

    if i != 1:
        ax.plot(MF_x, MF_y_dict[i], '-', markersize=2, color=u'#ff7f0e')

ax.tick_params(axis='both', which='major', labelsize=16)
ax.set_xlabel(r'Rescaled infectivity, $\lambda$', size=16)
ax.set_ylabel(r'Density of infected nodes, $\rho^{*}$', size=16)
# ax.set_xlim(0.2,2.2)
ax.set_ylim(-0.01,0.8);
ax.set_yticks([0,0.2,0.4,0.6,0.8]);

lgd = ax.legend(fontsize=13, handlelength=1, handletextpad=0.3, borderaxespad=0.2,
                loc='lower right', labelspacing=0.2, borderpad=0.4)  
ax.add_artist(lgd)

h = plt.plot([],[],'-', color=u'#ff7f0e', markersize=2, label='MF')
lgd = plt.legend(handles=h, loc=(0.02,0.82), frameon=False, fontsize=14, handlelength=1, borderpad=0.1)
ax.add_artist(lgd)

ax.annotate('SIS', (2,0.38), fontsize=13)

plt.tight_layout()
